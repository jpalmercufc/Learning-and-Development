# %%
import requests
import pandas as pd
import time

# %%
#Keys

api_key = "AIzaSyDZRrTLNUswQ14Hbu61eQlvmUJBtFNTwY0"
channel_id = 'UC2UXDak6o7rBm23k3Vv5dww'

# %%
# make API call

response = requests.get('https://api.github.com').json()
response
# Out:
# {'current_user_url': 'https://api.github.com/user',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
# ...

# %%
#making the API call


api_key = "AIzaSyDZRrTLNUswQ14Hbu61eQlvmUJBtFNTwY0"
channel_id =  'UCW8Ews7tdKKkBT6GdtQaXvQ'
url = 'https://www.googleapis.com/youtube/v3/search?key='+api_key+"&channelId="+channel_id+"&part=snippet,id&order=date&maxResults=1000" #+pagetoken



response = requests.get(url).json()
response['items'][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': '0br25juoeoxrqUFeUiupuuesmf0',
#  'id': {'kind': 'youtube#video', 'videoId': 'Ih6G5hnn30Q'},
#  'snippet': {'publishedAt': '2023-05-24T17:00:20Z',
#   'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#   'title': '[Part 2]: Exploring Decision Tree Classifiers For A Facebook Data Science Project of Movie Ratings',
#   'description': 'Welcome back to our data project series on Rotten Tomatoes! In this video, we dive into the decision tree classifier, a popular ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ih6G5hnn30Q/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Ih6G5hnn30Q/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Ih6G5hnn30Q/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'StrataScratch',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2023-05-24T17:00:20Z'}}

# %%
videos = response['items']
videos[0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': '0br25juoeoxrqUFeUiupuuesmf0',
#  'id': {'kind': 'youtube#video', 'videoId': 'Ih6G5hnn30Q'},
#  'snippet': {'publishedAt': '2023-05-24T17:00:20Z',
#   'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#   'title': '[Part 2]: Exploring Decision Tree Classifiers For A Facebook Data Science Project of Movie Ratings',
#   'description': 'Welcome back to our data project series on Rotten Tomatoes! In this video, we dive into the decision tree classifier, a popular ...',
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ih6G5hnn30Q/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/Ih6G5hnn30Q/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/Ih6G5hnn30Q/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'StrataScratch',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2023-05-24T17:00:20Z'}}

# %%
# This seems to work to grab the statistics about the individual video

video_id = 'Ih6G5hnn30Q'
url = 'https://www.googleapis.com/youtube/v3/videos?key='+api_key+"&channelId="+channel_id+"&id="+video_id+"&part=statistics,id&order=date&maxResults=1"

statsresponse = requests.get(url).json()
statsresponse
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'wP-GhK-BeCq-2q71cCH9gK0n618',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'lboQL0tMkEOgk6pdUeaeR1kFJPg',
#    'id': 'Ih6G5hnn30Q',
#    'statistics': {'viewCount': '305',
#     'likeCount': '11',
#     'favoriteCount': '0',
#     'commentCount': '0'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
#statsresponse['items'][0]['statistics']['viewCount']
#statsresponse['items'][0]['statistics']['likeCount']
statsresponse['items'][0]['statistics']['favoriteCount']
#statsresponse['items'][0]['statistics']['commentCount']
# Out:
# '0'

# %%
# The above call doesn't really give us much helpful info so let's make a second call to grab the statistics about the video

api_key = "AIzaSyDZRrTLNUswQ14Hbu61eQlvmUJBtFNTwY0"
channel_id =  'UCW8Ews7tdKKkBT6GdtQaXvQ'
url = 'https://www.googleapis.com/youtube/v3/search?key='+api_key+"&channelId="+channel_id+"&part=snippet,id&order=date&maxResults=1000" #+pagetoken


data = []

for v in response['items']:

    videoid = v['id']['videoId']
    videotitle = v['snippet']['title']
    videodate = v['snippet']['publishTime']
    #data.append((videoid,videotitle,videodate))

    #need to pass in information about the current video we're looping through to grab the stats

    statsurl = 'https://www.googleapis.com/youtube/v3/videos?key='+api_key+"&channelId="+channel_id+"&id="+videoid+"&part=statistics,id&order=date&maxResults=1"

    statsresponse = requests.get(statsurl).json()

    views = statsresponse['items'][0]['statistics']['viewCount']
    likes = statsresponse['items'][0]['statistics']['likeCount']
    faves = statsresponse['items'][0]['statistics']['favoriteCount']
    comments = statsresponse['items'][0]['statistics']['commentCount']

    data.append((videoid,videotitle,videodate,views,likes,faves,comments))

df2 = pd.DataFrame.from_records(data, columns=['VideoID','Title','PublishDate','Views','Likes','Faves','Comments'])
print(df2.dtypes)
df2.head(5)
# Out:
# VideoID        object
# Title          object
# PublishDate    object
# Views          object
# Likes          object
# Faves          object
# Comments       object
# dtype: object
#        VideoID                                              Title  \
# 0  Ih6G5hnn30Q  [Part 2]: Exploring Decision Tree Classifiers ...
# 1  REGDQyCBY0I  Rotten Tomatoes Movie Rating Prediction - Data...
# 2  cM12QtrhdLo  [Part 1]: Exploring and Visualizing Data For A...
# 3  A9QzeBFj5GY  Python Pandas: Understanding Percentage Rankin...
# 4  Cg66PLiW9L0  Data Ranking: Python Pandas and SQL Equivalent...
#
#             PublishDate Views Likes Faves Comments
# 0  2023-05-24T17:00:20Z   306    12     0        0
# 1  2023-05-23T17:00:16Z   124     2     0        0
# 2  2023-05-17T17:00:31Z   481    13     0        0
# 3  2023-05-16T17:00:05Z   213    10     0        0
# 4  2023-05-10T17:00:07Z   418    14     0        1

# %%
df2['PublishDate'].str.split("T",expand=True)[0].head(5)
# Out:
# 0    2023-05-24
# 1    2023-05-23
# 2    2023-05-17
# 3    2023-05-16
# 4    2023-05-10
# Name: 0, dtype: object

# %%
df2[['Views','Likes','Faves','Comments']] = df2[['Views','Likes','Faves','Comments']].astype(int)
#df2[['VideoID','Title']] = df2[['VideoID','Title']].astype(str) # Turns out you don't need to convert from object - it will always shows strings as 'object'
df2['PublishDate'] = df2['PublishDate'].str.split("T",expand=True)[0]

print(df2.dtypes)
df2
# Out:
# VideoID        object
# Title          object
# PublishDate    object
# Views           int64
# Likes           int64
# Faves           int64
# Comments        int64
# dtype: object
#         VideoID                                              Title  \
# 0   Ih6G5hnn30Q  [Part 2]: Exploring Decision Tree Classifiers ...
# 1   REGDQyCBY0I  Rotten Tomatoes Movie Rating Prediction - Data...
# 2   cM12QtrhdLo  [Part 1]: Exploring and Visualizing Data For A...
# 3   A9QzeBFj5GY  Python Pandas: Understanding Percentage Rankin...
# 4   Cg66PLiW9L0  Data Ranking: Python Pandas and SQL Equivalent...
# 5   d2neUrrUSu0  Python for Data Analysis: Probability And Bino...
# 6   MO1TY636-YA  A Python Approach to Solving Probability Inter...
# 7   f6P1nuQXsC0  Using IFNULL() Function in MySQL to Avoid Null...
# 8   rbRYsAgwPBA  Using IFNULL() on a Google SQL Interview Question
# 9   IWo8H8U_Ugk  Sorting and Ranking Data in Python: An Overvie...
# ...

# %%
# note that if you dont put the .str in the below then it'll just return the first 4 rows of data

df2['PublishDate'].groupby(df2['PublishDate'].str[:4]).count()
# Out:
# PublishDate
# 2022    17
# 2023    33
# Name: PublishDate, dtype: int64

# %%
#import pandas as pd
from datetime import datetime

df2['PublishDate'] = pd.to_datetime(df2['PublishDate'])

df2.dtypes
# Out:
# VideoID                object
# Title                  object
# PublishDate    datetime64[ns]
# Views                   int64
# Likes                   int64
# Faves                   int64
# Comments                int64
# dtype: object

# %%
df = pd.DataFrame(columns = ['VideoID', 'Title', 'PublishDate'])
df
# Out:
# Empty DataFrame
# Columns: [VideoID, Title, PublishDate]
# Index: []

# %%
data = []

for v in response['items']:

    videoid = v['id']['videoId']
    videotitle = v['snippet']['title']
    videodate = v['snippet']['publishTime']
    
    data.append((videoid,videotitle,videodate))

df2 = pd.DataFrame.from_records(data, columns=['VideoID','Title','PublishDate'])
df2.head(5)
# Out:
#        VideoID                                              Title  \
# 0  Ih6G5hnn30Q  [Part 2]: Exploring Decision Tree Classifiers ...
# 1  REGDQyCBY0I  Rotten Tomatoes Movie Rating Prediction - Data...
# 2  cM12QtrhdLo  [Part 1]: Exploring and Visualizing Data For A...
# 3  A9QzeBFj5GY  Python Pandas: Understanding Percentage Rankin...
# 4  Cg66PLiW9L0  Data Ranking: Python Pandas and SQL Equivalent...
#
#             PublishDate
# 0  2023-05-24T17:00:20Z
# 1  2023-05-23T17:00:16Z
# 2  2023-05-17T17:00:31Z
# 3  2023-05-16T17:00:05Z
# 4  2023-05-10T17:00:07Z
