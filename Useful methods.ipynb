# %%
import pandas as pd
import numpy as np


df = pd.read_csv('C:\\Users\\palmerj2\\OneDrive - Verastar\\Documents\\Anaconda bits\\housing_dataset.csv')


print(df.head(3))
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100

# %%
print(df.tail(3))
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income ocean_proximity  \
# 20637        1007         433         1.7000          INLAND
# 20638         741         349         1.8672          INLAND
# 20639        1387         530         2.3886          INLAND
#
#        median_house_value
# 20637               92300
# 20638               84700
# 20639               89400

# %%
# info() function used to get a concisesummary of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   ocean_proximity     20640 non-null  object
#  9   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
# dtypes shows the data types of each column

df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# ocean_proximity        object
# median_house_value      int64
# dtype: object

# %%
# .shape can be used to show the row and column count for a dataframe

df.shape
# Out:
# (20640, 10)

# %%
# the .describe() method shows a statistical summary of the dataset

df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# The sample method allows you to reutrn a rnadom slice of the data

df.sample(n=10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12595    -121.49     38.54                  37         1655           393.0
# 507      -122.28     37.83                  52         3108           813.0
# 15350    -117.30     33.26                  23         1678           275.0
# 272      -122.19     37.78                  52         1070           193.0
# 1626     -122.16     37.86                  36         3359           493.0
# 19064    -122.44     38.34                  25         3106           715.0
# 3753     -118.39     34.17                  40         1696           372.0
# 8371     -118.34     33.98                  45         1298           294.0
# 6260     -117.95     34.04                  36         1044           200.0
# 155      -122.23     37.81                  52         2315           292.0
#
#        population  households  median_income ocean_proximity  \
# 12595         841         355         1.6932          INLAND
# ...

# %%
# Identify missing values using the isnull method

df.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
# ...

# %%
# Or count those missing values using the below

df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# median_house_value      0
# dtype: int64

# %%
# Check to see if a dataset contains any null values by combining the "isna" and "any" methods

df.isna().any()
# Out:
# longitude             False
# latitude              False
# housing_median_age    False
# total_rooms           False
# total_bedrooms         True
# population            False
# households            False
# median_income         False
# ocean_proximity       False
# median_house_value    False
# dtype: bool

# %%
# Nunique counts the number of unique entries over columns or rows

df.nunique()
# Out:
# longitude               844
# latitude                862
# housing_median_age       52
# total_rooms            5926
# total_bedrooms         1923
# population             3888
# households             1815
# median_income         12928
# ocean_proximity           5
# median_house_value     3842
# dtype: int64

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity', 'median_house_value'],
#       dtype='object')

# %%
df.memory_usage()
# Out:
# Index                    128
# longitude             165120
# latitude              165120
# housing_median_age    165120
# total_rooms           165120
# total_bedrooms        165120
# population            165120
# households            165120
# median_income         165120
# ocean_proximity       165120
# median_house_value    165120
# dtype: int64

# %%
# Nsmallest

df.nsmallest(5,'median_house_value')
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2521     -122.74     39.71                  16          255            73.0
# 2799     -117.02     36.40                  19          619           239.0
# 9188     -117.86     34.24                  52          803           267.0
# 19802    -123.17     40.31                  36           98            28.0
# 5887     -118.33     34.15                  39          493           168.0
#
#        population  households  median_income ocean_proximity  \
# 2521           85          38         1.6607          INLAND
# 2799          490         164         2.1000          INLAND
# 9188          628         225         4.1932          INLAND
# 19802          18           8         0.5360          INLAND
# 5887          259         138         2.3667       <1H OCEAN
#
#        median_house_value
# 2521                14999
# 2799                14999
# 9188                14999
# 19802               14999
# ...

# %%
# Nlargest
df.nlargest(5,'median_house_value')
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 89     -122.27     37.80                  52          249            78.0
# 459    -122.25     37.87                  52          609           236.0
# 493    -122.24     37.86                  52         1668           225.0
# 494    -122.24     37.85                  52         3726           474.0
# 509    -122.23     37.83                  52         2990           379.0
#
#      population  households  median_income ocean_proximity  median_house_value
# 89          396          85         1.2434        NEAR BAY              500001
# 459        1349         250         1.1696        NEAR BAY              500001
# 493         517         214         7.8521        NEAR BAY              500001
# 494        1366         496         9.3959        NEAR BAY              500001
# 509         947         361         7.8772        NEAR BAY              500001

# %%
# loc and iloc
# loc: select by labels
# iloc: select by position

# select the first 6 rows of data (index beings at 0) for the two chosen columns using the below

df.loc[:5,['median_income','median_house_value']]
# Out:
#    median_income  median_house_value
# 0         8.3252              452600
# 1         8.3014              358500
# 2         7.2574              352100
# 3         5.6431              341300
# 4         3.8462              342200
# 5         4.0368              269700

# %%
# for iloc we use position to identify both the rows and the columns we want to return

df.iloc[:4,:6]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
#
#    population
# 0         322
# 1        2401
# 2         496
# 3         558

# %%
df[0:4]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300

# %%
# sort_values() 

df.sort_values(by='median_house_value', ascending = False)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10667    -117.88     33.55                  27         2278           316.0
# 16916    -122.34     37.57                  52         2635           408.0
# 16946    -122.33     37.55                  33         2199           312.0
# 8877     -118.49     34.04                  48         2381           345.0
# 8878     -118.50     34.04                  52         3000           374.0
# ...          ...       ...                 ...          ...             ...
# 5887     -118.33     34.15                  39          493           168.0
# 9188     -117.86     34.24                  52          803           267.0
# 2521     -122.74     39.71                  16          255            73.0
# 2799     -117.02     36.40                  19          619           239.0
# 19802    -123.17     40.31                  36           98            28.0
#
# ...

# %%
# group by can be combined with a variety of other methods to group and sort the data into manageable chunks

group = df[['housing_median_age','median_house_value','total_rooms']].groupby(['housing_median_age','total_rooms']).mean()

group.sort_values(by='median_house_value',ascending=False)
# Out:
#                                 median_house_value
# housing_median_age total_rooms
# 52                 6186                   500001.0
# 22                 4443                   500001.0
#                    17591                  500001.0
# 39                 2040                   500001.0
#                    2125                   500001.0
# ...                                            ...
#                    493                     17500.0
# 52                 803                     14999.0
# 19                 619                     14999.0
# 16                 255                     14999.0
# 36                 98                      14999.0
#
# [19332 rows x 1 columns]

# %%
# insert a column into a dataframe using "insert". By default the column is added at the end of the dataframe
# but can alter this using indexing

# new column
new_col=np.random.randn(20640)

#insert the new column at position 8
df.insert(8,'new_column',new_col)

# %%
# drop the same column using drop and axis = 1 (axis = 0 will delete rows)

df = df.drop(['new_column'], axis = 1)

df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...
